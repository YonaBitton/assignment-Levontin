# %% [markdown]
# # Assignment Levontin

# %% [markdown]
# ## Imports

# %%
import sys, seaborn, matplotlib

print("Python :", sys.executable)
print("seaborn :", seaborn.__version__, "->", seaborn.__file__)
print("matplotlib :", matplotlib.__version__, "->", matplotlib.__file__)

print("\nChemins sys.path contenant 'spyder-env' :")
for p in sys.path:
    if "spyder-env" in p.lower():
        print("  ", p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import sys, seaborn, matplotlib
#       3 print("Python :", sys.executable)
#       4 print("seaborn :", seaborn.__version__, "->", seaborn.__file__)
#
# File ~\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\spyder-env\Lib\site-packages\seaborn\__init__.py:9
#       7 from .categorical import *  # noqa: F401,F403
#       8 from .distributions import *  # noqa: F401,F403
# ----> 9 from .matrix import *  # noqa: F401,F403
#      10 from .miscplot import *  # noqa: F401,F403
#      11 from .axisgrid import *  # noqa: F401,F403
#
# File ~\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\spyder-env\Lib\site-packages\seaborn\matrix.py:12
#       9 import pandas as pd
#      10 from scipy.cluster import hierarchy
# ---> 12 from . import cm
#      13 from .axisgrid import Grid
# ...

# %%
import numpy as np
import pandas as pd
#import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\yonab\AppData\Local\pypoetry\Cache\virtualenvs\assignment-levontin-P00nE7-J-py3.10\Scripts\python.exe

# %%
import sys

print("Python :", sys.executable)
# Out:
# Python : c:\Users\yonab\AppData\Local\pypoetry\Cache\virtualenvs\assignment-levontin-P00nE7-J-py3.10\Scripts\python.exe

# %%
import matplotlib


print("Matplotlib :", matplotlib.__version__)
# Out:
# Matplotlib : 3.10.7

# %%
#import seaborn as sns
import seaborn as sns
print("Seaborn :", seaborn.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 #import seaborn as sns
# ----> 2 import seaborn as sns
#       3 print("Seaborn :", seaborn.__version__)
#
# File ~\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\spyder-env\Lib\site-packages\seaborn\__init__.py:9
#       7 from .categorical import *  # noqa: F401,F403
#       8 from .distributions import *  # noqa: F401,F403
# ----> 9 from .matrix import *  # noqa: F401,F403
#      10 from .miscplot import *  # noqa: F401,F403
#      11 from .axisgrid import *  # noqa: F401,F403
#
# File ~\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\spyder-env\Lib\site-packages\seaborn\matrix.py:12
#       9 import pandas as pd
#      10 from scipy.cluster import hierarchy
# ---> 12 from . import cm
#      13 from .axisgrid import Grid
#      14 from .utils import (
#      15     despine,
# ...

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import seaborn as sns
#
# File ~\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\spyder-env\Lib\site-packages\seaborn\__init__.py:9
#       7 from .categorical import *  # noqa: F401,F403
#       8 from .distributions import *  # noqa: F401,F403
# ----> 9 from .matrix import *  # noqa: F401,F403
#      10 from .miscplot import *  # noqa: F401,F403
#      11 from .axisgrid import *  # noqa: F401,F403
#
# File ~\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\spyder-env\Lib\site-packages\seaborn\matrix.py:12
#       9 import pandas as pd
#      10 from scipy.cluster import hierarchy
# ---> 12 from . import cm
#      13 from .axisgrid import Grid
#      14 from .utils import (
#      15     despine,
#      16     axis_ticklabels_overlap,
#    (...)
#      19     _draw_figure,
#      20 )
#
# ...

# %%
import sys, matplotlib, seaborn as sns

print("Python :", sys.executable)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import sys, matplotlib, seaborn as sns
#       3 print("Python :", sys.executable)
#
# File ~\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\spyder-env\Lib\site-packages\seaborn\__init__.py:9
#       7 from .categorical import *  # noqa: F401,F403
#       8 from .distributions import *  # noqa: F401,F403
# ----> 9 from .matrix import *  # noqa: F401,F403
#      10 from .miscplot import *  # noqa: F401,F403
#      11 from .axisgrid import *  # noqa: F401,F403
#
# File ~\AppData\Roaming\Microsoft\Windows\Start Menu\Programs\spyder-env\Lib\site-packages\seaborn\matrix.py:12
#       9 import pandas as pd
#      10 from scipy.cluster import hierarchy
# ---> 12 from . import cm
#      13 from .axisgrid import Grid
#      14 from .utils import (
#      15     despine,
# ...

# %% [markdown]
# ## Data loading
